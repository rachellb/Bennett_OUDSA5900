# %%
import os
import pandas as pd
import numpy as np

# Get data
parent = os.path.dirname(os.getcwd())
dataPath = os.path.join(parent, 'Data/Hepatitis/hepatitis.data')

df = pd.read_csv(dataPath, header=None)
df.columns = ['Label','Age','Sex','Steroid','Antivirals','Fatigue',
             'Malaise','Anorexia','LiverBig','LiverFirm','SpleenPalpable',
             'Spiders','Ascites','Varices','Bilirubin','AlkPhosphate','Sgot',
             'Albumin','Protime','Histology']

# %%
df.head()
# Out:
#    Label  Age  Sex Steroid  Antivirals Fatigue Malaise Anorexia LiverBig  \
# 0      2   30    2       1           2       2       2        2        1
# 1      2   50    1       1           2       1       2        2        1
# 2      2   78    1       2           2       1       2        2        2
# 3      2   31    1       ?           1       2       2        2        2
# 4      2   34    1       2           2       2       2        2        2
#
#   LiverFirm SpleenPalpable Spiders Ascites Varices Bilirubin AlkPhosphate  \
# 0         2              2       2       2       2      1.00           85
# 1         2              2       2       2       2      0.90          135
# 2         2              2       2       2       2      0.70           96
# 3         2              2       2       2       2      0.70           46
# 4         2              2       2       2       2      1.00            ?
#
#   Sgot Albumin Protime  Histology
# 0   18     4.0       ?          1
# ...

# %%
df.describe()
# Out:
#             Label         Age         Sex  Antivirals   Histology
# count  155.000000  155.000000  155.000000  155.000000  155.000000
# mean     1.793548   41.200000    1.103226    1.845161    1.451613
# std      0.406070   12.565878    0.305240    0.362923    0.499266
# min      1.000000    7.000000    1.000000    1.000000    1.000000
# 25%      2.000000   32.000000    1.000000    2.000000    1.000000
# 50%      2.000000   39.000000    1.000000    2.000000    1.000000
# 75%      2.000000   50.000000    1.000000    2.000000    2.000000
# max      2.000000   78.000000    2.000000    2.000000    2.000000

# %%
df.replace(to_replace='?', value=np.NaN, inplace=True)
df.replace(to_replace=1, value=0, inplace=True) # Binary variables set no=1 for some reason
df.replace(to_replace=2, value=1, inplace=True) # Binary variables set yes=2 for some reason

# %%
df.isnull().sum()
# Out:
# Label              0
# Age                0
# Sex                0
# Steroid            1
# Antivirals         0
# Fatigue            1
# Malaise            1
# Anorexia           1
# LiverBig          10
# LiverFirm         11
# SpleenPalpable     5
# Spiders            5
# Ascites            5
# Varices            5
# Bilirubin          6
# AlkPhosphate      29
# Sgot               4
# Albumin           16
# Protime           67
# Histology          0
# dtype: int64

# %%
df.dtypes
# Out:
# Label     int64
# 1         int64
# 2         int64
# 3        object
# 4         int64
# 5        object
# 6        object
# 7        object
# 8        object
# 9        object
# 10       object
# 11       object
# 12       object
# 13       object
# 14       object
# 15       object
# 16       object
# 17       object
# 18       object
# 19        int64
# dtype: object

# %%
for c in df.columns:
    print ("---- %s ---" % c)
    print (df[c].value_counts())
# Out:
# ---- Label ---
# 0    155
# Name: Label, dtype: int64
# ---- Age ---
# 38    8
# 34    8
# 30    8
# 36    7
# 50    6
# 39    6
# 51    6
# 45    5
# 37    5
# 42    5
# 28    5
# 54    5
# 44    5
# 32    4
# 27    4
# 47    4
# 23    4
# 31    4
# 33    3
# 41    3
# 40    3
# 52    3
# 49    3
# 56    3
# 61    3
# 25    3
# 20    3
# 48    2
# 57    2
# 58    2
# 62    2
# 24    2
# 22    2
# 35    2
# 26    1
# 78    1
# 43    1
# 72    1
# 46    1
# 53    1
# 59    1
# 60    1
# 64    1
# 65    1
# 66    1
# 67    1
# 69    1
# 70    1
# 7     1
# Name: Age, dtype: int64
# ---- Sex ---
# 0    155
# Name: Sex, dtype: int64
# ---- Steroid ---
# 2    78
# 1    76
# Name: Steroid, dtype: int64
# ---- Antivirals ---
# 0    155
# Name: Antivirals, dtype: int64
# ---- Fatigue ---
# 1    100
# 2     54
# Name: Fatigue, dtype: int64
# ---- Malaise ---
# 2    93
# 1    61
# Name: Malaise, dtype: int64
# ---- Anorexia ---
# 2    122
# 1     32
# Name: Anorexia, dtype: int64
# ...

# %%
df['Label'] = np.where(df['Label'] == 2, 0, df['Label'])  # Change to 0 if 2, otherwise leave as is
df['Label'] = np.where(df['Label'] == 1, 1, df['Label'])  # Change to 1 if 4, otherwise leave as is
